# %%
import pandas as pd

# %%
dataset = pd.read_csv("Dataset\Steel_industry_data.csv")
dataset['date']
# Out:
# 0        01/01/2018 00:15
# 1        01/01/2018 00:30
# 2        01/01/2018 00:45
# 3        01/01/2018 01:00
# 4        01/01/2018 01:15
#                ...
# 35035    31/12/2018 23:00
# 35036    31/12/2018 23:15
# 35037    31/12/2018 23:30
# 35038    31/12/2018 23:45
# 35039    31/12/2018 00:00
# Name: date, Length: 35040, dtype: object

# %%
dataset['date'] = pd.to_datetime(dataset['date'], format='%d/%m/%Y %H:%M')
dataset.set_index('date', inplace=False)
dataset
# Out:
#                      date  Usage_kWh  Lagging_Current_Reactive.Power_kVarh  \
# 0     2018-01-01 00:15:00       3.17                                  2.95
# 1     2018-01-01 00:30:00       4.00                                  4.46
# 2     2018-01-01 00:45:00       3.24                                  3.28
# 3     2018-01-01 01:00:00       3.31                                  3.56
# 4     2018-01-01 01:15:00       3.82                                  4.50
# ...                   ...        ...                                   ...
# 35035 2018-12-31 23:00:00       3.85                                  4.86
# 35036 2018-12-31 23:15:00       3.74                                  3.74
# 35037 2018-12-31 23:30:00       3.78                                  3.17
# 35038 2018-12-31 23:45:00       3.78                                  3.06
# 35039 2018-12-31 00:00:00       3.67                                  3.02
#
#        Leading_Current_Reactive_Power_kVarh  CO2(tCO2)  \
# ...

# %%
import matplotlib.pyplot as plt

# Create a time series plot
plt.figure(figsize=(12, 6))
plt.plot(dataset.index, dataset['Usage_kWh'])

# Configure the x-axis to display the date labels
plt.gca().xaxis.set_major_locator(plt.MaxNLocator(prune='both'))


plt.title('Electricity Consumption Over Time')
plt.xlabel('Date')
plt.ylabel('Usage_kWh')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()

plt.show()

# %%
pip install statsmodels
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

plot_acf(dataset['Usage_kWh'])
plot_pacf(dataset['Usage_kWh'])
plt.show()
